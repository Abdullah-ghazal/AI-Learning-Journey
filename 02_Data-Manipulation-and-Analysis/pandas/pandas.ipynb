# %% [markdown]
# ---
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# ---
# # **1) Introduction to Pandas**
# ---

# %% [markdown]
# ---
# ### ***1.1 What is Pandas?***
# - **Pandas = Panel data**
# > is a powerful open-source Python library used for data manipulation, analysis, and cleaning. It provides high-level data structures and functions designed to make working with structured (tabular, multidimensional, time series) data easy and intuitive.
#
#
# **💠 Usage:**
#
#   - Load and analyze datasets (CSV, Excel, SQL, JSON, etc.)
#
#   - Clean or transform data (missing values, duplicates, formatting)
#
#   - Perform statistical or mathematical operations
#
#   - Group, filter, and summarize data
#
#   - Merge, join, or reshape datasets
#
#   - Work with time-series data
#
# ---

# %% [markdown]
# ---
# ### ***1.2 Why Pandas Is Important?***
#
#   - Fast and efficient for large datasets
#
#   - User-friendly syntax for manipulating tabular data
#
#   - Works well with NumPy, Matplotlib, Scikit-learn, and other data science tools
#
#   - Excellent support for missing data, grouping, and time series
#
#   - Wide adoption in data science, finance, academia, and industry
#
# ---

# %% [markdown]
# ---
# ### ***1.3 Installation***
#
# - **`Using pip`**
#
#   ```
#   pip install pandas
#   ```
#
# - **`Using pip`** (with upgrade)
#   ```
#   pip install --upgrade pandas
#   ```
#
# - **`Using conda`**
#   ```
#   conda install pandas
#   ```
#
# ----

# %% [markdown]
# ---
# ### ***1.4 Basic Import***
#
#   ```
#   import pandas as pd
#
#   ```
# ---

# %%
  import pandas as pd

# %% [markdown]
# ---
# ### ***1.5 Series VS DataFrame***
#
# - **`Series`** is a one-dimensional labeled array capable of holding data of any type (integer, string, float, etc.).
# - **`DataFrame`** is a two-dimensional labeled data structure with columns and rows.
#
# ---
# ![image.png](data:image/png;base64,...)
#
# ---

# %%
# Series
import pandas as pd

s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# DataFrame
import pandas as pd

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
})
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# ---
# # **2) Pandas Data Structures**
# ---

# %% [markdown]
# ---
# ## **2.1 Series**
#
# #### **a) Creation:**
# ```python
# pd.Series(data=None, index=None, dtype=None, name=None, copy=False)
# ```
# ▶ **Definition** – A Series is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.). It's like a column in a spreadsheet or a single column from a DataFrame.
#
# 💠 **Usage:** Use Series when you need to work with a single column of data or when you want to perform operations on a one-dimensional dataset with labeled indices.

# %%
# Create series from list:
numbers = pd.Series([1, 2, 3, 4])
print(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# Create series with custom indices
fruits = pd.Series(['Apple', 'Banana', 'Orange'], index=['a', 'b', 'c'])
print(fruits)
# Out:
# a     Apple
# b    Banana
# c    Orange
# dtype: object

# %%
# Create Series from dictionary with mixed datatypes
data = {'name' : 'Abdullah', 'age': 22, 'salary': 0.0, 'married': False}
person_data = pd.Series(data)

print(person_data)
# Out:
# name       Abdullah
# age              22
# salary          0.0
# married       False
# dtype: object

# %%
# Create Series with datetime index
dates = pd.date_range('2024-01-01', periods=5, freq='D')
sales = pd.Series([100, 150, 200, 175, 300], index=dates, name='Daily Sales')
print(sales)
# Out:
# 2024-01-01    100
# 2024-01-02    150
# 2024-01-03    200
# 2024-01-04    175
# 2024-01-05    300
# Freq: D, Name: Daily Sales, dtype: int64

# %% [markdown]
# ---
# #### **b) Attributes:**
#
# - ### **`dtype`**
# ```python
# series.dtype
# ```
# ▶ **Definition** – Returns the data type of the Series elements.
#
# 💠 **Usage:** Use to check what type of data your Series contains (int64, float64, object, bool, etc.).

# %%
numbers = pd.Series([1, 2, 3])
print(numbers.dtype)
# Out:
# int64

# %% [markdown]
# * **`index`**
#
# ```python
# series.index
# ```
# ▶ **Definition** – Returns the index (row labels) of the Series.
#
# 💠 **Usage:** Use to access or modify the labels of your Series data.

# %%
fruits = pd.Series(['apple', 'banana'], index=['a', 'b'])
print(fruits.index)
# Out:
# Index(['a', 'b'], dtype='object')

# %% [markdown]
# - ### **`values`**
#
# ```python
# series.values
# ```
# ▶ **Definition** – Returns the underlying data as a NumPy array.
#
# 💠 **Usage:** Use when you need to access the raw data without index labels.

# %%
numbers = pd.Series([1, 2, 3])
print(numbers.values)
# Out:
# [1 2 3]

# %% [markdown]
# - ### **`name`**
#
# ```python
# series.name
# ```
# ▶ **Definition** – Returns or sets the name of the Series.
#
# 💠 **Usage:** Use to give your Series a descriptive name, especially useful when working with multiple Series.

# %%
sales = pd.Series([100, 200, 300], name='Monthly Sales')
print(sales.name)
# Out:
# Monthly Sales

# %% [markdown]
# - ### **`shape`**
#
# ```python
# series.shape
# ```
# ▶ **Definition** – Returns a tuple representing the dimensions of the Series.
#
# 💠 **Usage:** Use to quickly check the size of your Series.

# %%
numbers = pd.Series([1, 2, 3, 4, 5])
print(numbers.shape)
# Out:
# (5,)

# %% [markdown]
# ---
# #### **c) Methods**
#
# - ### **`head()`**
#
# ```python
# series.head(n=5)
# ```
# ▶ **Definition** – Returns the first n rows of the Series.
#
# 💠 **Usage:** Use to quickly preview the beginning of your data, especially useful for large datasets.

# %%
large_series = pd.Series(range(100))
print(large_series.head(3))  # Shows first 3 elements
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %% [markdown]
# - ### **`tail()`**
#
# ```python
# series.tail(n=5)
# ```
# ▶ **Definition** – Returns the last n rows of the Series.
#
# 💠 **Usage:** Use to quickly preview the end of your data.

# %%
large_series = pd.Series(range(100))
print(large_series.tail(3))
# Out:
# 97    97
# 98    98
# 99    99
# dtype: int64

# %% [markdown]
# - ### **`unique()`**
#
# ```python
# series.unique()
# ```
#
# ▶ **Definition** – Returns unique values in the Series as a NumPy array.
#
# 💠 **Usage:** Use to find all distinct values in your Series, removing duplicates.

# %%
colors = pd.Series(['red', 'blue', 'red', 'green', 'blue'])
print(colors.unique())
# Out:
# ['red' 'blue' 'green']

# %% [markdown]
# - ### **`nunique()`**
#
# ```python
# series.nunique(dropna=True)
# ```
# Parameter:
# - dropna (bool, default True):
#
#   - If **True**: Ignores NaN values in the count.
#
#   - If **False**: Includes NaN as a unique value.
#
# ▶ **Definition** – Returns the number of unique values in the Series.
#
# 💠 **Usage:** Use to count how many distinct values exist in your Series.

# %%
colors = pd.Series(['red', 'blue', 'red', 'green', 'blue'])
print(colors.nunique())  # 3

# %% [markdown]
# - ### **`value_counts()`**
#
# ```python
# series.value_counts(normalize=False, sort=True, ascending=False, dropna=True)
# ```
# ▶ **Definition** – Returns a Series containing counts of unique values.
#
# 💠 **Usage:** Use to analyze the frequency distribution of values in your Series.

# %%
colors = pd.Series(['red', 'blue', 'red', 'green', 'blue', 'red'])
print(colors.value_counts())
# Out:
# red      3
# blue     2
# green    1
# Name: count, dtype: int64

# %% [markdown]
# - ### **`isna()`**
#
# ```python
# series.isna()
# ```
# ▶ **Definition** – Returns a boolean Series showing which values are missing (NaN).
#
# 💠 **Usage:** Use to identify missing values in your data.

# %%
data = pd.Series([1, 2, None, 4])
print(data.isna())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# - ### **`notna()`**
#
# ```python
# series.notna()
# ```
# ▶ **Definition** – Returns a boolean Series showing which values are not missing.
#
# 💠 **Usage:** Use to identify non-missing values in your data.

# %%
data = pd.Series([1, 2, None, 4])
print(data.notna())
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %% [markdown]
# - ### **`dropna()`**
#
# ```python
# series.dropna(axis=0, inplace=False)
# ```
# ▶ **Definition** – Returns a Series with missing values removed.
#
# 💠 **Usage:** Use to clean your data by removing rows with missing values.

# %%
data = pd.Series([1, 2, None, 4, None, 6])
clean_data = data.dropna()
print(clean_data)

# remove row = 2, 4
# Out:
# 0    1.0
# 1    2.0
# 3    4.0
# 5    6.0
# dtype: float64

# %% [markdown]
# - ### **`fillna()`**
#
# ```python
# series.fillna(value=None, method=None, inplace=False)
# ```
# ▶ **Definition** – Fills missing values with a specified value or method.
#
# 💠 **Usage:** Use to replace missing values with meaningful substitutes.

# %%
data = pd.Series([1, 2, None, 4])
filled_data = data.fillna(99)  # Replace NaN with 99
print(filled_data)
# Out:
# 0     1.0
# 1     2.0
# 2    99.0
# 3     4.0
# dtype: float64

# %%
# Forward fill
# fills missing (NaN) values by propagating the last valid (non-null) value forward.
filled_forward = data.fillna(method='ffill')
print(filled_forward)
# Out:
# 0    1.0
# 1    2.0
# 2    2.0
# 3    4.0
# dtype: float64
# /tmp/ipython-input-17-2416294261.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filled_forward = data.fillna(method='ffill')

# %% [markdown]
# - ### **`astype()`**
#
# ```python
# series.astype(dtype, copy=True, errors='raise')
# ```
# ▶ **Definition** – Converts the Series to a specified data type.
#
# 💠 **Usage:** Use to change the data type of your Series elements.

# %%
numbers_str = pd.Series(['1', '2', '3'])
numbers_int = numbers_str.astype(int)
print(numbers_int.dtype)
# Out:
# int64

# %% [markdown]
# - ### **`map()`**
#
# ```python
# series.map(arg, na_action=None)
# ```
# ▶ **Definition** – Maps values of Series according to input correspondence (dict, Series, or function).
#
# 💠 **Usage:** Use to transform values based on a mapping or function.

# %%
sizes = pd.Series(['S', 'M', 'L', 'S', 'L'])
size_map = {'S': 'Small', 'M': 'Medium', 'L': 'Large'}
full_sizes = sizes.map(size_map)
print(full_sizes)
# Out:
# 0     Small
# 1    Medium
# 2     Large
# 3     Small
# 4     Large
# dtype: object

# %% [markdown]
# - ### **`apply()`**
#
# ```python
# series.apply(func, convert_dtype=True, args=())
# ```
# ▶ **Definition** – Applies a function along the Series.
#
# 💠 **Usage:** Use to apply custom functions to transform your data.

# %%
import math

numbers = pd.Series([1, 2, 3, 4, 5])
squared = numbers.apply(lambda x: x**2)
print(squared)


sqrt_numbers = numbers.apply(math.sqrt)
print(sqrt_numbers)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64
# 0    1.000000
# 1    1.414214
# 2    1.732051
# 3    2.000000
# 4    2.236068
# dtype: float64

# %% [markdown]
# - ### **`copy()`**
#
# ```python
# series.copy(deep=True)
# ```
# ▶ **Definition** – Creates a copy of the Series.
#
# 💠 **Usage:** Use to create an independent copy of your Series to avoid modifying the original.

# %%
original = pd.Series([1, 2, 3])
copy_series = original.copy()
copy_series[0] = 999
print(original)
print(copy_series)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
# 0    999
# 1      2
# 2      3
# dtype: int64

# %% [markdown]
# ---
# ## **2.2 DataFrame**
#
# #### **a) Creation:**
#
# ```python
# pd.DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)
# ```
# ▶ **Definition** – A DataFrame is a 2-dimensional labeled data structure with columns of potentially different types.
# - It's like a spreadsheet or SQL table, or a dictionary of Series objects.
#
# 💠 **Usage:** Use DataFrame when you need to work with tabular data with multiple columns and rows, perform data analysis, or manipulate structured datasets.

# %%
# Create DataFrame from dictionary
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'Paris', 'London']}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London

# %%
# Create DataFrame from list of dictionaries
employees = [
    {'name': 'Alice', 'department': 'Engineering', 'salary': 90000, 'years': 3},
    {'name': 'Bob', 'department': 'Marketing', 'salary': 70000, 'years': 5},
    {'name': 'Charlie', 'department': 'Engineering', 'salary': 95000, 'years': 2}
]
df = pd.DataFrame(employees)
print(df)
# Out:
#       name   department  salary  years
# 0    Alice  Engineering   90000      3
# 1      Bob    Marketing   70000      5
# 2  Charlie  Engineering   95000      2

# %%
# Create DataFrame with custom index
df_custom = pd.DataFrame(
    data=[[1, 2, 3], [4, 5, 6], [7, 8, 9]],
    index=['row1', 'row2', 'row3'],
    columns=['A', 'B', 'C']
)

print(df_custom)
# Out:
#       A  B  C
# row1  1  2  3
# row2  4  5  6
# row3  7  8  9

# %% [markdown]
# ---
# #### **b) Attributes**
#
# - **`columns`**
#
# ```python
# df.columns
# ```
# ▶ **Definition** – Returns the column labels of the DataFrame.
#
# 💠 **Usage:** Use to access or modify column names.

# %%
df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
print(df.columns)
df.columns = ['X', 'Y']
# Out:
# Index(['A', 'B'], dtype='object')

# %% [markdown]
# - **`index`**
#
# ```python
# df.index
# ```
# ▶ **Definition** – Returns the index (row labels) of the DataFrame.
#
# 💠 **Usage:** Use to access or modify row labels.

# %%
df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
print(df.index)
# change indices
df.index = ['first', 'second']
print(df.index)
# Out:
# RangeIndex(start=0, stop=2, step=1)
# Index(['first', 'second'], dtype='object')

# %% [markdown]
# - **`dtypes`**
#
# ```python
# df.dtypes
# ```
# ▶ **Definition** – Returns the data types of each column.
#
# 💠 **Usage:** Use to check the data types of all columns at once.

# %%
df = pd.DataFrame({'A': [1, 2], 'B': [3.5, 4.5], 'C': ['x', 'y']})
print(df.dtypes)
# Out:
# A      int64
# B    float64
# C     object
# dtype: object

# %% [markdown]
# - **`shape`**
#
# ```python
# df.shape
# ```
# ▶ **Definition** – Returns a tuple representing the dimensions of the DataFrame (rows, columns).
#
# 💠 **Usage:** Use to quickly check the size of your DataFrame.

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.shape)
# Out:
# (3, 2)

# %% [markdown]
# - **`size`**
#
# ```python
# df.size
# ```
# ▶ **Definition** – Returns the total number of elements in the DataFrame.
#
# 💠 **Usage:** Use to get the total count of all cells in the DataFrame.

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.size)
# Out:
# 6

# %% [markdown]
# - **`values`**
#
# ```python
# df.values
# ```
# ▶ **Definition** – Returns the underlying data as a NumPy array.
#
# 💠 **Usage:** Use when you need to access the raw data without column names or index.

# %%
df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
print(df.values)
# Out:
# [[1 3]
#  [2 4]]

# %% [markdown]
# - **`axes`**
#
# ```python
# df.axes
# ```
# ▶ **Definition** – Returns a list of the row and column axes.
#
# 💠 **Usage:** Use to get both index and columns information together.

# %%
df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=2, step=1), Index(['A', 'B'], dtype='object')]

# %% [markdown]
# - **`ndim`**
#
# ```python
# df.ndim
# ```
# ▶ **Definition** – Returns the number of dimensions (always 2 for DataFrame).
#
# 💠 **Usage:** Use to confirm you're working with a 2D structure.

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.ndim)  # 2
# Out:
# 2

# %% [markdown]
# - **`empty`**
#
# ```python
# df.empty
# ```
# ▶ **Definition** – Returns True if DataFrame is empty (no data).
#
# 💠 **Usage:** Use to check if your DataFrame contains any data.

# %%
empty_df = pd.DataFrame()
print(empty_df.empty)  # True

df = pd.DataFrame({'A': [1, 2]})
print(df.empty)  # False
# Out:
# True
# False

# %% [markdown]
# #### **c) Methods**
#
# - **`head()`**
#
# ```python
# df.head(n=5)
# ```
# ▶ **Definition** – Returns the first n rows of the DataFrame.
#
# 💠 **Usage:** Use to quickly preview the beginning of your data.

# %%
df = pd.DataFrame({'A': range(50, 100, 10), 'B': range(100, 200, 20)})
print(df.head(3))

# Note: 'A' , 'B' must have the same length
# Out:
#     A    B
# 0  50  100
# 1  60  120
# 2  70  140

# %% [markdown]
# - **`tail()`**
#
# ```python
# df.tail(n=5)
# ```
# ▶ **Definition** – Returns the last n rows of the DataFrame.
#
# 💠 **Usage:** Use to quickly preview the end of your data.

# %%
df = pd.DataFrame({'A': range(100), 'B': range(100, 200)})
print(df.tail(3))
# Out:
#      A    B
# 97  97  197
# 98  98  198
# 99  99  199

# %% [markdown]
# - **`describe()`**
#
# ```python
# df.describe(percentiles=None, include=None, exclude=None)
# ```
# ▶ **Definition** – Generates descriptive statistics for numerical columns.
#
# 💠 **Usage:** Use to get a quick statistical summary of your numerical data.
#   - Shows => count, mean, std, min, 25%, 50%, 75%, max

# %%
df = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]})
print(df.describe())
# Out:
#               A          B
# count  5.000000   5.000000
# mean   3.000000  30.000000
# std    1.581139  15.811388
# min    1.000000  10.000000
# 25%    2.000000  20.000000
# 50%    3.000000  30.000000
# 75%    4.000000  40.000000
# max    5.000000  50.000000

# %% [markdown]
# - **`info()`**
#
# ```python
# df.info(verbose=None, buf=None, max_cols=None, memory_usage=None, null_counts=None)
# ```
# ▶ **Definition** – Prints a concise summary of the DataFrame including data types and memory usage.
#
# 💠 **Usage:** Use to get an overview of your DataFrame's structure and identify data quality issues.
# - Shows => column names, non-null count, data types, memory usage

# %%
df = pd.DataFrame({'A': [1, 2, None], 'B': ['x', 'y', 'z']})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       2 non-null      float64
#  1   B       3 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 180.0+ bytes

# %% [markdown]
# - **`memory_usage()`**
#
# ```python
# df.memory_usage(index=True, deep=False)
# ```
# ▶ **Definition** – Returns the memory usage of each column in bytes.
#
# 💠 **Usage:** Use to analyze memory consumption and optimize DataFrame performance.

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': ['long string', 'another long string', 'more text']})
print(df.memory_usage(deep=True))
# Out:
# Index    132
# A         24
# B        210
# dtype: int64

# %% [markdown]
# - **`select_dtypes()`**
#
# ```python
# df.select_dtypes(include=None, exclude=None)
# ```
# ▶ **Definition** – Returns a subset of DataFrame columns based on data types.
#
# 💠 **Usage:** Use to filter columns by their data types for specific operations.

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [1.5, 2.5, 3.5], 'C': ['x', 'y', 'z']})
numeric_cols = df.select_dtypes(include=['number'])
print(numeric_cols)  # Only columns A and B
# Out:
#    A    B
# 0  1  1.5
# 1  2  2.5
# 2  3  3.5

# %%
string_cols = df.select_dtypes(include=['object'])
print(string_cols)  # Only column C
# Out:
#    C
# 0  x
# 1  y
# 2  z

# %% [markdown]
# - **`assign()`**
#
# ```python
# df.assign(**kwargs)
# ```
# ▶ **Definition** – Assigns new columns to a DataFrame, returning a new DataFrame.
#
# 💠 **Usage:** Use to add new columns based on existing data or calculations.

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df_new = df.assign(C=df['A'] + df['B'], D=lambda x: x['A'] * 2)
print(df_new)
# Note:
# Original df unchanged, df_new has columns A, B, C, D
# Out:
#    A  B  C  D
# 0  1  4  5  2
# 1  2  5  7  4
# 2  3  6  9  6

# %% [markdown]
# - **`copy()`**
#
# ```python
# df.copy(deep=True)
# ```
# ▶ **Definition** – Creates a copy of the DataFrame.
#
# 💠 **Usage:** Use to create an independent copy to avoid modifying the original DataFrame.

# %%
original = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
copy_df = original.copy()
copy_df.loc[0, 'A'] = 999
print(original)
print(copy_df)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#      A  B
# 0  999  4
# 1    2  5
# 2    3  6

# %% [markdown]
# ---
# ## **2.3 Index Objects**
# ---
#
# #### **a) Types**
#
# - **`Index`**
#
# ```python
# pd.Index(data=None, dtype=None, name=None)
# ```
# ▶ **Definition**
#   - The basic index object for pandas objects.
#   - Immutable array implementing an ordered, sliceable set.
#
# 💠 **Usage:** Use as a general-purpose index for any data type.

# %%
idx = pd.Index(['a', 'b', 'c', 'd'])
df = pd.DataFrame({'values': [1, 2, 3, 4]}, index=idx)
print(df)
# Out:
#    values
# a       1
# b       2
# c       3
# d       4

# %% [markdown]
# - **`DatetimeIndex`**
#
# ```python
# pd.DatetimeIndex(data=None, freq=None, tz=None, name=None)
# ```
# ▶ **Definition** – Index for datetime values, enabling time-series functionality.
#
# 💠 **Usage:** Use for time-series data and date-based operations.

# %%
dates = pd.date_range('2024-01-01', periods=5, freq='D')
df = pd.DataFrame({'sales': [100, 150, 200, 175, 300]}, index=dates)
print(df)
# Enables time-series operations like resampling
# Out:
#             sales
# 2024-01-01    100
# 2024-01-02    150
# 2024-01-03    200
# 2024-01-04    175
# 2024-01-05    300

# %% [markdown]
# - **`TimedeltaIndex`**
#
# ```python
# pd.TimedeltaIndex(data=None, unit=None, freq=None, name=None)
# ```
# ▶ **Definition** – Index for timedelta values (duration/time differences).
#
# 💠 **Usage:** Use when working with time differences or durations

# %%
td_idx = pd.TimedeltaIndex(['1 days', '2 days', '3 days'])
df = pd.DataFrame({'progress': [25, 50, 75]}, index=td_idx)
print(df)
# Out:
#         progress
# 1 days        25
# 2 days        50
# 3 days        75

# %% [markdown]
# - **`PeriodIndex`**
#
# ```python
# pd.PeriodIndex(data=None, freq=None, name=None)
# ```
# ▶ **Definition** – Index for period values (time spans like months, quarters).
#
# 💠 **Usage:** Use for data that represents time periods rather than specific time points.

# %%
periods = pd.period_range('2024-01', periods=4, freq='M')
df = pd.DataFrame({'revenue': [10000, 12000, 15000, 11000]}, index=periods)
print(df)
# Out:
#          revenue
# 2024-01    10000
# 2024-02    12000
# 2024-03    15000
# 2024-04    11000

# %% [markdown]
# - **`CategoricalIndex`**
#
# ```python
# pd.CategoricalIndex(data=None, categories=None, ordered=None, name=None)
# ```
# ▶ **Definition** – Index for categorical data with optional ordering.
#
# 💠 **Usage:** Use when your index has a limited set of categories, especially for memory efficiency.

# %%
cat_idx = pd.CategoricalIndex(['small', 'medium', 'large', 'small'],
                              categories=['small', 'medium', 'large'],
                              ordered=True)
df = pd.DataFrame({'price': [10, 20, 30, 15]}, index=cat_idx)
print(df)
# Out:
#         price
# small      10
# medium     20
# large      30
# small      15

# %% [markdown]
# - **`MultiIndex`**
#
# ```python
# pd.MultiIndex.from_tuples(tuples, names=None)
# pd.MultiIndex.from_arrays(arrays, names=None)
# pd.MultiIndex.from_product(iterables, names=None)
# ```
# ▶ **Definition** – Multi-level or hierarchical index for advanced data organization.
#
# 💠 **Usage:** Use when you need hierarchical indexing for complex data structures.

# %%
# From tuples
tuples = [('A', 1), ('A', 2), ('B', 1), ('B', 2)]
multi_idx = pd.MultiIndex.from_tuples(tuples, names=['letter', 'number'])
df = pd.DataFrame({'values': [10, 20, 30, 40]}, index=multi_idx)
print(df)
# Out:
#                values
# letter number
# A      1           10
#        2           20
# B      1           30
#        2           40

# %%
# From arrays
arrays = [['A', 'A', 'B', 'B'], [1, 2, 1, 2]]
multi_idx2 = pd.MultiIndex.from_arrays(arrays, names=['letter', 'number'])
df = pd.DataFrame({'values': [10, 20, 30, 40]}, index=multi_idx2)
print(df)
# Out:
#                values
# letter number
# A      1           10
#        2           20
# B      1           30
#        2           40

# %% [markdown]
# -----------
# #### **Methods:**
#
# - **`is_unique`**
#
# ```python
# index.is_unique
# ```
# ▶ **Definition** – Returns True if the index has no duplicate values.
#
# 💠 **Usage:** Use to check if your index contains unique values only.

# %%
idx1 = pd.Index([1, 2, 3, 4])
print(idx1.is_unique)  # True

idx2 = pd.Index([1, 2, 2, 3])
print(idx2.is_unique)  # False
# Out:
# True
# False

# %% [markdown]
# - **`equals()`**
#
# ```python
# index1.equals(index2)
# ```
# ▶ **Definition** – Checks if two indexes are equal (same values and order).
#
# 💠 **Usage:** Use to compare two indexes for equality.

# %%
idx1 = pd.Index([1, 2, 3])
idx2 = pd.Index([1, 2, 3])
idx3 = pd.Index([3, 2, 1])

print(idx1.equals(idx2))  # True
print(idx1.equals(idx3))  # False
# Out:
# True
# False

# %% [markdown]
# - **`identical()`**
#
# ```python
# index1.identical(index2)
# ```
# ▶ **Definition** – Checks if two indexes are identical (same values, order, and metadata).
#
# 💠 **Usage:** Use when you need to check not just values but also metadata like names.

# %%
idx1 = pd.Index([1, 2, 3], name='numbers')
idx2 = pd.Index([1, 2, 3], name='numbers')
idx3 = pd.Index([1, 2, 3], name='values')

print(idx1.identical(idx2))
print(idx1.identical(idx3))
# Out:
# True
# False

# %% [markdown]
# - **`union()`**
#
# ```python
# index1.union(index2, sort=None)
# ```
# ▶ **Definition** – Returns the union of two indexes (all unique values from both).
#
# 💠 **Usage:** Use to combine indexes and get all unique values.

# %%
idx1 = pd.Index([1, 2, 3])
idx2 = pd.Index([3, 4, 5])
union_idx = idx1.union(idx2)
print(union_idx)
# Out:
# Index([1, 2, 3, 4, 5], dtype='int64')

# %% [markdown]
# - **`intersection()`**
#
# ```python
# index1.intersection(index2, sort=False)
# ```
# ▶ **Definition** – Returns the intersection of two indexes (common values).
#
# 💠 **Usage:** Use to find common values between two indexes.

# %%
idx1 = pd.Index([1, 2, 3, 4])
idx2 = pd.Index([3, 4, 5, 6])
intersection_idx = idx1.intersection(idx2)
print(intersection_idx)
# Out:
# Index([3, 4], dtype='int64')

# %% [markdown]
# - **`difference()`**
#
# ```python
# index1.difference(index2, sort=None)
# ```
# ▶ **Definition** – Returns values in the first index that are not in the second.
#
# 💠 **Usage:** Use to find values that exist in one index but not another.

# %%
idx1 = pd.Index([1, 2, 3, 4])
idx2 = pd.Index([3, 4, 5, 6])
diff_idx = idx1.difference(idx2)
print(diff_idx)  # Index([1, 2])
# Out:
# Index([1, 2], dtype='int64')

# %% [markdown]
# - **`drop_duplicates()`**
#
# ```python
# index.drop_duplicates(keep='first')
# ```
# ▶ **Definition** – Returns index with duplicate values removed.
#
# 💠 **Usage:** Use to remove duplicate values from an index.

# %%
idx = pd.Index([1, 2, 2, 3, 3, 4])
unique_idx = idx.drop_duplicates()
print(unique_idx)
# Out:
# Index([1, 2, 3, 4], dtype='int64')

# %% [markdown]
# - **`get_loc()`**
#
# ```python
# index.get_loc(key)
# ```
# ▶ **Definition** – Returns the integer position of a label in the index.
#
# 💠 **Usage:** Use to find the position of a specific value in the index.

# %%
idx = pd.Index(['a', 'b', 'c', 'd'])
position = idx.get_loc('c')
print(position)
# Out:
# 2

# %% [markdown]
# - **`get_indexer()`**
#
# ```python
# index.get_indexer(target, method=None, limit=None, tolerance=None)
# ```
# ▶ **Definition** – Returns an array of integers indicating positions of target values.
#
# 💠 **Usage:** Use to find positions of multiple values at once.

# %%
idx = pd.Index(['a', 'b', 'c', 'd'])
positions = idx.get_indexer(['b', 'd', 'a'])
print(positions)
# Out:
# [1 3 0]

# %% [markdown]
# - **`set_names()`**
#
# ```python
# index.set_names(names, level=None, inplace=False)
# ```
# ▶ **Definition** – Sets the name(s) of the index.
#
# 💠 **Usage:** Use to give descriptive names to your index, especially useful for MultiIndex.

# %%
idx = pd.Index([1, 2, 3, 4])
named_idx = idx.set_names('ID')
print(named_idx.name)
# Out:
# ID

# %%
# For MultiIndex
multi_idx = pd.MultiIndex.from_tuples([('A', 1), ('B', 2)])
named_multi = multi_idx.set_names(['Letter', 'Number'])
print(named_multi.names)
# Out:
# ['Letter', 'Number']

# %% [markdown]
# - **`to_list()`**
#
# ```python
# index.to_list()
# ```
# ▶ **Definition** – Returns the index as a Python list.
#
# 💠 **Usage:** Use when you need to convert the index to a standard Python list.

# %%
idx = pd.Index(['a', 'b', 'c', 'd'])
index_list = idx.to_list()
print(index_list)
print(type(index_list))
# Out:
# ['a', 'b', 'c', 'd']
# <class 'list'>

# %%
# Create a complex MultiIndex DataFrame
arrays = [['A', 'A', 'B', 'B'], ['X', 'Y', 'X', 'Y']]
multi_idx = pd.MultiIndex.from_arrays(arrays, names=['Group', 'Subgroup'])
df = pd.DataFrame({
    'Value1': [1, 2, 3, 4],
    'Value2': [10, 20, 30, 40]
}, index=multi_idx)

print(df)
print("\nIndex names:", df.index.names)
print("Index levels:", df.index.levels)
print("Is unique:", df.index.is_unique)

# Working with MultiIndex
print("\nGroup A data:")
print(df.loc['A'])

print("\nSpecific cell (A, X):")
print(df.loc[('A', 'X'), 'Value1'])

# Index operations
print("\nUnique values in first level:")
print(df.index.get_level_values(0).unique())

print("\nUnique values in second level:")
print(df.index.get_level_values(1).unique())
# Out:
#                 Value1  Value2
# Group Subgroup
# A     X              1      10
#       Y              2      20
# B     X              3      30
#       Y              4      40
#
# Index names: ['Group', 'Subgroup']
# Index levels: [['A', 'B'], ['X', 'Y']]
# Is unique: True
#
# Group A data:
#           Value1  Value2
# Subgroup
# X              1      10
# Y              2      20
#
# Specific cell (A, X):
# 1
#
# Unique values in first level:
# Index(['A', 'B'], dtype='object', name='Group')
#
# Unique values in second level:
# Index(['X', 'Y'], dtype='object', name='Subgroup')
